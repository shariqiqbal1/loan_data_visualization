# %%
import os
import numpy as np
import pandas as pd
import datetime 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('loan.csv')

# %%
df
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# 5    xqd20160706             PAIDOFF        300      7       9/9/2016
# 6    xqd20160007             PAIDOFF       1000     30       9/9/2016
# 7    xqd20160008             PAIDOFF       1000     30       9/9/2016
# 8    xqd20160909             PAIDOFF       1000     30       9/9/2016
# 9    xqd20160010             PAIDOFF        800     15      9/10/2016
# 10   xqd20160011             PAIDOFF        300      7      9/10/2016
# 11   xqd20160012             PAIDOFF       1000     15      9/10/2016
# ...

# %%
df[['education','loan_status']]
# Out:
#                 education         loan_status
# 0    High School or Below             PAIDOFF
# 1                Bechalor             PAIDOFF
# 2                Bechalor             PAIDOFF
# 3                 college             PAIDOFF
# 4                 college             PAIDOFF
# 5         Master or Above             PAIDOFF
# 6                 college             PAIDOFF
# 7                 college             PAIDOFF
# 8                 college             PAIDOFF
# 9                 college             PAIDOFF
# 10                college             PAIDOFF
# 11   High School or Below             PAIDOFF
# 12                college             PAIDOFF
# 13                college             PAIDOFF
# 14   High School or Below             PAIDOFF
# 15                college             PAIDOFF
# 16   High School or Below             PAIDOFF
# 17   High School or Below             PAIDOFF
# 18   High School or Below             PAIDOFF
# ...

# %%
pd.isnull(df).any()
# Out:
# Loan_ID           False
# loan_status       False
# Principal         False
# terms             False
# effective_date    False
# due_date          False
# paid_off_time      True
# past_due_days      True
# age               False
# education         False
# Gender            False
# dtype: bool

# %%
df.dropna()
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 400  xqd20160401  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 401  xqd20160402  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 402  xqd20320403  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 403  xqd20160404  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 404  xqd20190405  COLLECTION_PAIDOFF        800     15       9/9/2016
# 405  xqd20160406  COLLECTION_PAIDOFF       1000     30      9/10/2016
# 406  xqd20160407  COLLECTION_PAIDOFF        800     15      9/10/2016
# 407  xqd20160408  COLLECTION_PAIDOFF       1000     30      9/10/2016
# 408  xqd20110409  COLLECTION_PAIDOFF       1000     30      9/10/2016
# 409  xqd20160410  COLLECTION_PAIDOFF       1000     15      9/10/2016
# 410  xqd20160411  COLLECTION_PAIDOFF        800     15      9/10/2016
# 411  xqd20160412  COLLECTION_PAIDOFF       1000     30      9/10/2016
# ...

# %%
df.groupby('Gender').loan_status.value_counts()
# Out:
# Gender  loan_status
# female  PAIDOFF                53
#         COLLECTION_PAIDOFF     14
#         COLLECTION             10
# male    PAIDOFF               247
#         COLLECTION             90
#         COLLECTION_PAIDOFF     86
# dtype: int64

# %%
df
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# 5    xqd20160706             PAIDOFF        300      7       9/9/2016
# 6    xqd20160007             PAIDOFF       1000     30       9/9/2016
# 7    xqd20160008             PAIDOFF       1000     30       9/9/2016
# 8    xqd20160909             PAIDOFF       1000     30       9/9/2016
# 9    xqd20160010             PAIDOFF        800     15      9/10/2016
# 10   xqd20160011             PAIDOFF        300      7      9/10/2016
# 11   xqd20160012             PAIDOFF       1000     15      9/10/2016
# ...

# %%
df = pd.read_csv('loan.csv')
df.dropna()
df[['Gender','loan_status']]
df = df[df['loan_status'] == 'PAIDOFF']
df[['Gender','loan_status']]
df.groupby('Gender').loan_status.value_counts().plot.pie(autopct='%.2f')

# %%
df = pd.read_csv('loan.csv')
df.dropna()
df[['Gender','loan_status']]
df = df[df['loan_status'] == 'COLLECTION_PAIDOFF']
df[['Gender','loan_status']]
df.groupby('Gender').loan_status.value_counts().plot.pie(autopct='%.2f')

# %%
df = pd.read_csv('loan.csv')
df.dropna()
df[['Gender','loan_status']]
df = df[df['loan_status'] == 'COLLECTION']
df[['Gender','loan_status']]
df.groupby('Gender').loan_status.value_counts().plot.pie(autopct='%.2f')

# %%
df = pd.read_csv('loan.csv')
df.dropna()
df
df[['Gender', 'education']]
df = df[df['Gender'] == 'male']
df[['Gender','education']]
df.groupby('Gender').education.value_counts().plot.pie(autopct='%.2f')

# %%
df = pd.read_csv('loan.csv')
df.dropna()
df
df[['Gender', 'education']]
df = df[df['Gender'] == 'female']
df[['Gender','education']]
df.groupby('Gender').education.value_counts().plot.pie(autopct='%.2f')

# %%
df = pd.read_csv('loan.csv')
df.dropna()
#df['bins'] = pd.cut(df['age'],bins=[18,25,45,65,120], labels=["18","18-25","25-45","45-65", "65+"])
df[np.abs(df.Principal-df.Principal.mean())<=(3*df.Principal.std())] #+-3 standard deviations
df = df[['Principal', 'education']]
df
df = df[df['education'] == 'college']
#df[['Gender','bins']]
df.groupby('education').plot.hist()
#hist(df.Gender, weights=df.Principal)
# Out:
# education
# college    Axes(0.125,0.125;0.775x0.775)
# dtype: object

# %%
df = pd.read_csv('loan.csv')
df.dropna()
#df['bins'] = pd.cut(df['age'],bins=[18,25,45,65,120], labels=["18","18-25","25-45","45-65", "65+"])
df[np.abs(df.Principal-df.Principal.mean())<=(3*df.Principal.std())] #+-3 standard deviations
df = df[['Principal', 'education']]
df
df = df[df['education'] == 'High School or Below']
#df[['Gender','bins']]
df.groupby('education').plot.hist()
#hist(df.Gender, weights=df.Principal)
# Out:
# education
# High School or Below    Axes(0.125,0.125;0.775x0.775)
# dtype: object

# %%
df = pd.read_csv('loan.csv')
df.dropna()
#df['bins'] = pd.cut(df['age'],bins=[18,25,45,65,120], labels=["18","18-25","25-45","45-65", "65+"])
df[np.abs(df.Principal-df.Principal.mean())<=(3*df.Principal.std())] #+-3 standard deviations
df = df[['Principal', 'education']]
df
df = df[df['education'] == 'college']
#df[['Gender','bins']]
df.groupby('education').plot.hist()
#hist(df.Gender, weights=df.Principal)
# Out:
# education
# college    Axes(0.125,0.125;0.775x0.775)
# dtype: object

# %%
df = pd.read_csv('loan.csv')
df.dropna()
#df['bins'] = pd.cut(df['age'],bins=[18,25,45,65,120], labels=["18","18-25","25-45","45-65", "65+"])
df[np.abs(df.Principal-df.Principal.mean())<=(3*df.Principal.std())] #+-3 standard deviations
df = df[['age', 'Principal']]
df.sort_values('age')
df.plot(kind='scatter', x='age', y='Principal', s=120, c=colors)

#df = pd.DataFrame({'x': 'age', 'y': 'Principal'})
#df.plot()

#.groupby("template").plot(x="date", y="score")
#df = df[df['Principal'] == 300]
#df[['Gender','bins']]
#df.groupby('Principal').plot(x="Principal", y="age")
#hist(df.Gender, weights=df.Principal)

# %%
df = pd.read_csv('loan.csv')
df.dropna()
#df['bins'] = pd.cut(df['age'],bins=[18,25,45,65,120], labels=["18","18-25","25-45","45-65", "65+"])
df[np.abs(df.Principal-df.Principal.mean())<=(3*df.Principal.std())] #+-3 standard deviations
df = df[['due_date', 'Principal']]
df.sort_values('due_date')
df.set_index('due_date').plot()
#df.plot(x='due_date', y='Principal')

#df.plot(kind='scatter', x='age', y='Principal', s=120, c=colors)

#df = pd.DataFrame({'x': 'age', 'y': 'Principal'})
#df.plot()

#.groupby("template").plot(x="date", y="score")
#df = df[df['Principal'] == 300]
#df[['Gender','bins']]
#df.groupby('Principal').plot(x="Principal", y="age")
#hist(df.Gender, weights=df.Principal)
